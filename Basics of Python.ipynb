# %% [markdown]
# ### WELCOME IN THE WORLD OF PYTHON

# %% [raw]
# MARKDOWN:-this option is used to make a heading, bold text,lists, tables,etc.

# %% [raw]
# Raw:- raw is used to keep text exactly as it is (or you can say that keep text unchanged).

# %% [raw]
# Code:- Used for write code.(Run python code).

# %%
#value assignment:-Value assignment means giving a value to a variable.we use = sign to assign a value inside a variable.

# %%
#1st method 
a=5 #here 'a' is a variable '=' is an assignment operator and '5' is value. 
b=10
c=a+b  #'c' contains value of a+b

# %%
c  #will give output of a+b
# Out:
# 15

# %%
#2nd method :- multiple value assignment, means we can assign value in a single line. see example:-
x,y,z=10,20,30

# %%
x
# Out:
# 10

# %%
y
# Out:
# 20

# %%
z
# Out:
# 30

# %%
#3rd method:- we can assign same value for multiple variables.
x=y=z=20

# %%
x
# Out:
# 20

# %%
y
# Out:
# 20

# %%
z
# Out:
# 20

# %%
#4th :-Reassigning value (changing value)
#in this example I have 1st variable x and assign value 4 in it but second variable is also x and 6 is assigned in it, then if we want to print x then we get last inisilized value.
x=4
x=6

# %%
x
# Out:
# 6

# %% [markdown]
# #### Variable naming:-

# %%
#variable naming :-we have to follow some rules before naming a variable.
#1:-Must start with a letter or underscore
_abc=5

# %%
_abc
# Out:
# 5

# %%
#2.Cannot start with a number
2name='vijaya'
# Out:
#   Cell In[21], line 2
#     2name='vijaya'
#     ^
# SyntaxError: invalid decimal literal

# %%
#3.Can contain letters, numbers, underscore
a=123

# %%
a
# Out:
# 123

# %%
a='vijaya'

# %%
a
# Out:
# 'vijaya'

# %%
a='abh_123'

# %%
a
# Out:
# 'abh_123'

# %%
#4.No spaces allowed
name of student='vijaya'       #you can write:- name_of_student='vijaya'
# Out:
#   Cell In[29], line 2
#     name of student='vijaya'
#          ^
# SyntaxError: invalid syntax

# %%
#5.Cannot use Python keywords
for=10      #U can use any other keyword instead of 'for', because for is a keyword.
# Out:
#   Cell In[32], line 2
#     for=10
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# #### KEYWORDS

# %% [raw]
# They have a fixed meaning and cannot b used as variable name.

# %%
#how to find keywords:-
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# #### DATATYPES:-

# %% [raw]
# 1.Numerical-int(integer value - positive-123 , negative-> -1,-2,-3), float(Decimnal numbers -> 2.3, 1.5), complex (4=3+4j)
# 2.String:- valuw which is closed inside ''(single quotes) or "" (double quotes).
# 3.Boolean:- only True or False

# %% [markdown]
# #### isinstance()

# %%
#It will give output in the form of boolean value.
isinstance(2,int)
# Out:
# True

# %%
isinstance(5.7,float)
# Out:
# True

# %%
isinstance('vijaya',str)
# Out:
# True

# %%
isinstance('vijaya',int)
# Out:
# False

# %% [markdown]
# #### Multi line Staement

# %%
#line changing using '\' backslash.
p=3+7+2\
+1+1

# %%
p
# Out:
# 14

# %%
#2nd example:-
name='vijaya '+'Sitamarhi '\
+'India'

# %%
name
# Out:
# 'vijaya Sitamarhi India'

# %% [markdown]
# #### type()

# %% [raw]
# type() function is used to find datatype of any particular value

# %%
sum=10+20+30
print(sum)
# Out:
# 60

# %%
type(sum)
# Out:
# int

# %%
name='Vijaya'

# %%
name
# Out:
# 'Vijaya'

# %%
type(name)
# Out:
# str

# %%
a=1.5
b=3.5
d=a+b

# %%
d
# Out:
# 5.0

# %%
type(d)
# Out:
# float

# %%
fail=False
fail
# Out:
# False

# %%
type(fail)
# Out:
# bool

# %% [markdown]
# #### len function / len() :- used to find length of a string.

# %%
name='vijaya'

# %%
len(name)
# Out:
# 6

# %%
#len() will find only the length of string, if you convert this a into str then it will print otherwise give TypeError
a=123456
len(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[67], line 3
#       1 #len() will find only the length of string, if you convert this a into str then it will print otherwise give TypeError
#       2 a=123456
# ----> 3 len(a)
#
# TypeError: object of type 'int' has no len()

# %%
a=123456
len(str(a))
# Out:
# 6

# %% [markdown]
# #### Call by index

# %% [raw]
# Indexing means accessing a single element from a sequence(like string, list, tuple). Index always starts from 0.
# let's see an example:-    name = "PYTHON"
# dry run:-
# Index	  0	  1	  2	  3	  4	  5
# Char	  P	  Y	  T	  H	  O	  N
# Neg(-ve) -1  -2  -3  -4  -5  -6

# %%
#indexing in string
name='vijaya'

# %%
name[0]
# Out:
# 'v'

# %%
name[1]
# Out:
# 'i'

# %%
name[2]
# Out:
# 'j'

# %%
name[3]
# Out:
# 'a'

# %%
name[-1]
# Out:
# 'a'

# %%
greetings='Good Morning Everyone'
print(greetings[-15])
# Out:
# o

# %%
#indexing in list
num=[10,1,23,4]

# %%
num[2]
# Out:
# 23

# %%
num[-1]
# Out:
# 4

# %%
#indexing in tuple

# %%
a=(2,45,5,65,5)

# %%
type(a) # type is used to find which type of value is it.
# Out:
# tuple

# %%
print(a[4])
# Out:
# 5

# %%
a[-5]
# Out:
# 2

# %%
#word = "INDIA" . 1.using positive index-I    2. using negative index-A
word='INDIA'

# %%
word[0]
# Out:
# 'I'

# %%
word[-1]
# Out:
# 'A'

# %% [markdown]
# ### Slicing:-Slicing means getting a part (piece) of a string, list, or tuple.

# %% [raw]
# cutting a part from a sequence.
# syntax:-[start:end:step]
# start- where to begin
# end- where to stop
# step- how many jumps

# %%
name='vijayasingh'

# %%
name[0:5]
# Out:
# 'vijay'

# %%
name[3:7]
# Out:
# 'ayas'

# %%
name[-4:5]
# Out:
# ''

# %%
name[-6:-2]
# Out:
# 'asin'

# %%
name[:]
# Out:
# 'vijayasingh'

# %%
name[-6:5:-1]
# Out:
# ''

# %%
name[-2:-1]
# Out:
# 'g'

# %% [markdown]
# #### Reverse a string/ list

# %%
text="PYTHON"

# %%
text[::-1]
# Out:
# 'NOHTYP'

# %%
text='PROGRAMMING'
text[0:7]
# Out:
# 'PROGRAM'

# %%
text[3:]
# Out:
# 'GRAMMING'

# %%
text[:5]
# Out:
# 'PROGR'

# %%
text[::2]
# Out:
# 'PORMIG'

# %%
text[::-1]
# Out:
# 'GNIMMARGORP'
